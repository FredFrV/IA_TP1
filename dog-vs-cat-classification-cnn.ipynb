# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import os 
import zipfile
from tqdm import tqdm
from glob import glob
from shutil import copy, move

# %% [markdown]
# ## Data Preparation

# %%
zipfile_dir = '../input/dogs-vs-cats/train.zip'
train_dir = zipfile.ZipFile(zipfile_dir, 'r')
train_dir.extractall()

zipfile_dir = '../input/dogs-vs-cats/test1.zip'
test_dir = zipfile.ZipFile(zipfile_dir, 'r')
test_dir.extractall()

# %%
TRAIN_DIR = './train'
TEST_DIR = './test1'

train_set = os.listdir(TRAIN_DIR)
test_set = os.listdir(TEST_DIR)

print('#train images: %s'%len(train_set))
print('#test images: %s'%len(test_set))
print(train_set[:5])
print(test_set[:5])
# Out:
# #train images: 25000
# #test images: 12500
# ['dog.10903.jpg', 'dog.5188.jpg', 'dog.8856.jpg', 'dog.969.jpg', 'dog.10884.jpg']
# ['10395.jpg', '9401.jpg', '9129.jpg', '3668.jpg', '4748.jpg']

# %%
dog_train_dir = './training/dog'
dog_val_dir = './validation/dog'
cat_train_dir = './training/cat'
cat_val_dir = './validation/cat'

file_dirs = [dog_train_dir, dog_val_dir, cat_train_dir, cat_val_dir]

for dir in file_dirs:
    os.makedirs(dir,exist_ok = True)

# %%
all_dogs = glob('./train/dog*jpg')
all_cats = glob('./train/cat*jpg')

print(len(all_dogs))
print(len(all_cats))
# Out:
# 12500
# 12500

# %%
from sklearn.model_selection import train_test_split

dogs_train, dogs_test = train_test_split(all_dogs, test_size=0.1, shuffle=True,random_state = 100)
cats_train, cats_test = train_test_split(all_cats, test_size=0.1, shuffle=True,random_state = 100)

# %%
for name in tqdm(dogs_train):
  copy(name , os.path.join(dog_train_dir , name.split('/')[-1]))
for name in tqdm(cats_train):
  copy(name , os.path.join(cat_train_dir , name.split('/')[-1]))
  
for name in tqdm(dogs_test):
  copy(name , os.path.join(dog_val_dir , name.split('/')[-1]))
for name in tqdm(cats_test):
  copy(name , os.path.join(cat_val_dir , name.split('/')[-1]))
# Out:
# 100%|██████████| 11250/11250 [00:02<00:00, 3967.32it/s]
# 100%|██████████| 11250/11250 [00:02<00:00, 5053.20it/s]
# 100%|██████████| 1250/1250 [00:00<00:00, 4398.66it/s]
# 100%|██████████| 1250/1250 [00:00<00:00, 4731.55it/s]

# %%
print(len(os.listdir(dog_train_dir)))
print(len(os.listdir(cat_train_dir)))
print(len(os.listdir(dog_val_dir)))
print(len(os.listdir(cat_val_dir)))
# Out:
# 11250
# 11250
# 1250
# 1250

# %% [markdown]
# ## Data Preprocessing

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

TRAINING_DIR = './training'
train_datagen = ImageDataGenerator(rescale=1 / 255)
train_generator = train_datagen.flow_from_directory(
    TRAINING_DIR,
    batch_size=64,
    class_mode='binary',
    target_size=(150, 150)
)

VALIDATION_DIR = './validation'
validation_datagen = ImageDataGenerator(rescale=1/255)
validation_generator = validation_datagen.flow_from_directory(
    VALIDATION_DIR,
    batch_size = 64,
    class_mode = 'binary',
    target_size = (150, 150)
)
# Out:
# Found 22500 images belonging to 2 classes.
# Found 2500 images belonging to 2 classes.

# %% [markdown]
# ## Model Creation

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, MaxPool2D, Flatten, Dropout

model = Sequential()
model.add(Conv2D(64, (3,3), strides=(1,1), padding='same', activation='relu',kernel_initializer='he_normal',input_shape=(150, 150, 3)))
model.add(Conv2D(64, (3,3), strides=(1,1), padding='same', activation='relu',kernel_initializer='he_normal'))
model.add(MaxPool2D((2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(128, (3,3), strides=(1,1), padding='same', activation='relu',kernel_initializer='he_normal'))
model.add(Conv2D(128, (3,3), strides=(1,1), padding='same', activation='relu',kernel_initializer='he_normal'))
model.add(Conv2D(128, (3,3), strides=(1,1), padding='same', activation='relu',kernel_initializer='he_normal'))
model.add(MaxPool2D((2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(256, (3,3), strides=(1,1), padding='same', activation='relu',kernel_initializer='he_normal'))
model.add(Dropout(0.4))
model.add(Conv2D(256, (3,3), strides=(1,1), padding='same', activation='relu',kernel_initializer='he_normal'))
model.add(Dropout(0.4))
model.add(Conv2D(256, (3,3), strides=(1,1), padding='same', activation='relu',kernel_initializer='he_normal'))
model.add(MaxPool2D((2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(512, (3,3), strides=(1,1), padding='same', activation='relu',kernel_initializer='he_normal'))
model.add(Dropout(0.4))
model.add(Conv2D(512, (3,3), strides=(1,1), padding='same', activation='relu',kernel_initializer='he_normal'))
model.add(Dropout(0.4))
model.add(Conv2D(512, (3,3), strides=(1,1), padding='same', activation='relu',kernel_initializer='he_normal'))
model.add(MaxPool2D((2,2)))
model.add(Dropout(0.4))

model.add(Flatten())
model.add(Dense(units=1024, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(units=1024, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(units=1024, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(units=1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_32 (Conv2D)           (None, 150, 150, 64)      1792
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 150, 150, 64)      36928
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 75, 75, 64)        0
# _________________________________________________________________
# dropout_32 (Dropout)         (None, 75, 75, 64)        0
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 75, 75, 128)       73856
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 75, 75, 128)       147584
# _________________________________________________________________
# conv2d_36 (Conv2D)           (None, 75, 75, 128)       147584
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 37, 37, 128)       0
# _________________________________________________________________
# dropout_33 (Dropout)         (None, 37, 37, 128)       0
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 37, 37, 256)       295168
# _________________________________________________________________
# dropout_34 (Dropout)         (None, 37, 37, 256)       0
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 37, 37, 256)       590080
# _________________________________________________________________
# dropout_35 (Dropout)         (None, 37, 37, 256)       0
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 37, 37, 256)       590080
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 18, 18, 256)       0
# _________________________________________________________________
# dropout_36 (Dropout)         (None, 18, 18, 256)       0
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 18, 18, 512)       1180160
# _________________________________________________________________
# dropout_37 (Dropout)         (None, 18, 18, 512)       0
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 18, 18, 512)       2359808
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 18, 18, 512)       0
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 18, 18, 512)       2359808
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 9, 9, 512)         0
# _________________________________________________________________
# dropout_39 (Dropout)         (None, 9, 9, 512)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 41472)             0
# _________________________________________________________________
# dense_16 (Dense)             (None, 1024)              42468352
# _________________________________________________________________
# dropout_40 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_17 (Dense)             (None, 1024)              1049600
# _________________________________________________________________
# dropout_41 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_18 (Dense)             (None, 1024)              1049600
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 1025
# =================================================================
# Total params: 52,351,425
# Trainable params: 52,351,425
# Non-trainable params: 0
# _________________________________________________________________

# %%
check_point_path = './best.h5'
model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath = check_point_path,
    monitor = 'val_accuracy',
    save_weights_only=False,
    save_best_only=True,
    verbose=1
)

# %%
model.compile(optimizer = tf.keras.optimizers.Adam(0.0005,decay=1e-5),
             loss = 'binary_crossentropy',
             metrics = ['acc'])

# %%
print('Num Params : ',model.count_params())
model_history = model.fit(
    train_generator,
    epochs=20,
    verbose=1,
    callbacks = [model_checkpoint],
    validation_data=validation_generator
)
# Out:
# Num Params :  52351425
# Epoch 1/20
# 352/352 [==============================] - 97s 271ms/step - loss: 2.0430 - acc: 0.4967 - val_loss: 0.6933 - val_acc: 0.5000
# Epoch 2/20
# 352/352 [==============================] - 95s 271ms/step - loss: 0.6730 - acc: 0.5574 - val_loss: 0.6203 - val_acc: 0.6460
# Epoch 3/20
# 352/352 [==============================] - 95s 269ms/step - loss: 0.6070 - acc: 0.6514 - val_loss: 0.5562 - val_acc: 0.7000
# Epoch 4/20
# 352/352 [==============================] - 95s 270ms/step - loss: 0.5793 - acc: 0.6841 - val_loss: 0.5577 - val_acc: 0.7308
# Epoch 5/20
# 352/352 [==============================] - 95s 270ms/step - loss: 0.5565 - acc: 0.7149 - val_loss: 0.5654 - val_acc: 0.7044
# Epoch 6/20
# 352/352 [==============================] - 95s 270ms/step - loss: 0.5269 - acc: 0.7358 - val_loss: 0.4811 - val_acc: 0.7768
# Epoch 7/20
# 352/352 [==============================] - 95s 270ms/step - loss: 0.4952 - acc: 0.7644 - val_loss: 0.4214 - val_acc: 0.8044
# Epoch 8/20
# 352/352 [==============================] - 95s 270ms/step - loss: 0.4470 - acc: 0.7896 - val_loss: 0.4105 - val_acc: 0.8360
# Epoch 9/20
# 352/352 [==============================] - 95s 270ms/step - loss: 0.3978 - acc: 0.8213 - val_loss: 0.3474 - val_acc: 0.8448
# Epoch 10/20
# 352/352 [==============================] - 95s 270ms/step - loss: 0.3441 - acc: 0.8496 - val_loss: 0.2741 - val_acc: 0.8776
# Epoch 11/20
# 352/352 [==============================] - 95s 270ms/step - loss: 0.2945 - acc: 0.8757 - val_loss: 0.2398 - val_acc: 0.9012
# Epoch 12/20
# 352/352 [==============================] - 95s 270ms/step - loss: 0.2669 - acc: 0.8874 - val_loss: 0.2764 - val_acc: 0.8816
# Epoch 13/20
# 352/352 [==============================] - 95s 270ms/step - loss: 0.2386 - acc: 0.8987 - val_loss: 0.2270 - val_acc: 0.9072
# Epoch 14/20
# 352/352 [==============================] - 95s 270ms/step - loss: 0.2260 - acc: 0.9043 - val_loss: 0.2041 - val_acc: 0.9172
# Epoch 15/20
# 352/352 [==============================] - 95s 270ms/step - loss: 0.1896 - acc: 0.9236 - val_loss: 0.1702 - val_acc: 0.9300
# Epoch 16/20
# 352/352 [==============================] - 96s 271ms/step - loss: 0.1844 - acc: 0.9261 - val_loss: 0.1863 - val_acc: 0.9228
# Epoch 17/20
# 352/352 [==============================] - 95s 270ms/step - loss: 0.1645 - acc: 0.9320 - val_loss: 0.2069 - val_acc: 0.9096
# Epoch 18/20
# 352/352 [==============================] - 95s 270ms/step - loss: 0.1647 - acc: 0.9331 - val_loss: 0.1446 - val_acc: 0.9416
# Epoch 19/20
# 352/352 [==============================] - 95s 270ms/step - loss: 0.1513 - acc: 0.9383 - val_loss: 0.1468 - val_acc: 0.9428
# Epoch 20/20
# 352/352 [==============================] - 95s 270ms/step - loss: 0.1468 - acc: 0.9414 - val_loss: 0.1395 - val_acc: 0.9412

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# Plotting Loss and Accuracy

# %%
# %matplotlib inline

import matplotlib.image  as mpimg
import matplotlib.pyplot as plt

#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc=model_history.history['acc']
val_acc=model_history.history['val_acc']
loss=model_history.history['loss']
val_loss=model_history.history['val_loss']

epochs=range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot(epochs, acc, 'r')
plt.plot(epochs, val_acc, 'b')
plt.title('Training and validation accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend(["Training Accuracy","Validation Accuracy"])
plt.show()

#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs, loss, 'r')
plt.plot(epochs, val_loss, 'b')
plt.title('Training and validation loss')
plt.title('Training and validation loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend(["Training Loss","Validation Loss"])
plt.show()

# Desired output. Charts with training and validation metrics.

# %%
test_file = os.listdir("./test1")
test_df = pd.DataFrame({
    'filename': test_file
})
test_df
# Out:
#         filename
# 0      10395.jpg
# 1       9401.jpg
# 2       9129.jpg
# 3       3668.jpg
# 4       4748.jpg
# ...          ...
# 12495    130.jpg
# 12496   3875.jpg
# 12497  11861.jpg
# 12498   3597.jpg
# 12499   5704.jpg
#
# [12500 rows x 1 columns]

# %%
TESTING_DIR = './test1'
test_generator = train_datagen.flow_from_dataframe(
    test_df,
    directory = TESTING_DIR,
    x_col='filename',
    y_col=None,
    batch_size=64,
    target_size=(150, 150),
    shuffle = False,
    class_mode = None
)
# Out:
# Found 12500 validated image filenames.

# %%
test_generator.reset()
y_pred = model.predict(test_generator)

# %% [markdown]
# To see the class mapping of dogs and cats, we have to see class_indices from training dataset

# %%
train_generator.class_indices
# Out:
# {'cat': 0, 'dog': 1}

# %% [markdown]
# Let's make labels

# %%
y_pred_classification = np.where(y_pred > 0.5, 1, 0)
y_pred_classification
# Out:
# array([[1],
#        [1],
#        [1],
#        ...,
#        [1],
#        [0],
#        [0]])

# %% [markdown]
# Seeing some results

# %%
test_generator.reset()
test_images = test_generator[0][:9]

fig, ax = plt.subplots(3,3)
fig.set_size_inches(10,10)
for i, img in enumerate(test_images):
    ax[i//3][i%3].imshow(img)
    if y_pred_classification[i]==1:
        label = 'Dog'
    else:
        label = 'Cat'
    ax[i//3][i%3].set_title(label)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-95-beaa00cfe038> in <module>
#       8         y_true.append(1)
#       9
# ---> 10 print(confusion_matrix(y_true, y_pred_classification))
#      11
#      12 test_generator.reset()
#
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     274
#     275     """
# --> 276     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     277     if y_type not in ("binary", "multiclass"):
#     278         raise ValueError("%s is not supported" % y_type)
#
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      79     y_pred : array or indicator matrix
#      80     """
# ---> 81     check_consistent_length(y_true, y_pred)
#      82     type_true = type_of_target(y_true)
#      83     type_pred = type_of_target(y_pred)
#
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     254     if len(uniques) > 1:
#     255         raise ValueError("Found input variables with inconsistent numbers of"
# --> 256                          " samples: %r" % [int(l) for l in lengths])
#     257
#     258
#
# ValueError: Found input variables with inconsistent numbers of samples: [25000, 12500]

# %% [markdown]
# Visualizing first 9 filters

# %%
model.layers

# %%
first_conv = model.layers[0]
output_layer1 = first_conv(test_images)[4]

print(output_layer1.shape)
fig, ax = plt.subplots(3,3)
fig.set_size_inches(10,10)
for i in range(9):
  ax[i//3][i%3].imshow(output_layer1[:,:,i])

# %% [markdown]
# ## Submition

# %%
submission = pd.read_csv('../input/dogs-vs-cats/sampleSubmission.csv')
submission['label'] = y_pred_classification
submission

# %%
submission.to_csv('submission.csv',index='False')
